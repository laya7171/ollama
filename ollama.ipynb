# %%
import ollama

# %%
response = ollama.generate(model = "gemma3:4b", prompt = "What is the capital of Nepal?", stream= True)

for text in response:
    print(text['response'], end="")
# Out:
# The capital of Nepal is **Kathmandu**.
#
# It's a bustling city located in the Kathmandu Valley. 😊
#
# Do you want to know anything else about Nepal or Kathmandu?
