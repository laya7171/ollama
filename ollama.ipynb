# %%
import ollama

# %%
response = ollama.generate(model = "gemma3:4b", prompt = "What is the capital of Nepal?")

# %%
print(response.response)
# Out:
# The capital of Nepal is **Kathmandu**.
#
# It’s a fascinating city with a rich history and culture!
#
# Do you want to know anything more about Kathmandu or Nepal in general?
